# %%
a=int(input("enter num 1 :"))
b=int(input("enter num 2 :"))
c=a+b
print(a+b)
print(c)
# Out:
# enter num 1 :10
# enter num 2 :20
# 30
# 30

# %%
str1="dkte"
str2="college"
print(str1+str2)
print(str1+' '+str2)
# Out:
# dktecollege
# dkte college

# %%
str1='dkte\t'
str2='college'
print(str1+str2)
# Out:
# dkte	college

# %%
str1='dkte :'
print(str1,len(str1))
str2='dkte college :'
print(str2,len(str2))
# Out:
# dkte : 6
# dkte college : 14

# %%
str1="dkte"
print(str1[0])
print(str1[1])
print(str1[2])
print(str1[3])
# Out:
# d
# k
# t
# e

# %%
str1=input("enter the string :")
print(str1[1:3])
print(str1[ :3])
print(str1[2: ])
print(str1[ : ])
# Out:
# enter the string :DKTE
# KT
# DKT
# TE
# DKTE

# %%
str1='dkte'
print(str1[-3:-1])
print(str1[ :-2])
print(str1[-2:-1])
# Out:
# kt
# dk
# t

# %%
str1='I am a programmer'
print(str1.startswith("I"))
print(str1.startswith(" I"))
print(str1.startswith("i"))
print(str1.endswith("er"))
print(str1.endswith("er."))
# Out:
# True
# False
# False
# True
# False

# %%
str1='dkte'
print(str1.upper())
str2="dkte"
print(str2.lower())
str3='dkte college'
print(str3.title())
# Out:
# DKTE
# dkte
# Dkte College

# %%
str1="dkte"
print(str1.isalpha())
str2="DKTE"
print(str2.isupper())
str3="dkte"
print(str3.islower())
str4="10"
print(str4.isdecimal())
str5="23.8"
print(str5.isnumeric())
# Out:
# True
# True
# True
# True
# False

# %%
city="ichalkaranji"
print(city.find("a"))
city='ichalkaranji'
print(city.count("i"))
city='ichalkaranji'
print(city.replace("a","s"))
# Out:
# 3
# 2
# ichslksrsnji
