# %%
#TUPLE

#PROGRAMME NO. 1
#EMPTY TUPLE
empty_tuple=()
print("empty_tuple",empty_tuple)
num1=(1)
print(type(num1))
# Out:
# empty_tuple ()
# <class 'int'>

# %%
#PROGRAMME NO.2
#TUPLE PACKING
packed_tuple=1,2,3
print(packed_tuple)
# Out:
# (1, 2, 3)

# %%
#PROGRAMME NO.3
#TUPLE METHODS
# 1)MAX
tuple=(24,68,15,20)
print(max(tuple))

# 2)
tuple2=("apple","mango","orange")
print(type(max(tuple2)))
# Out:
# 68
# <class 'str'>

# %%
#PROGRAMME NO. 5
#COUNT()
nums=(10,20,40,60,10,20)
print(nums.count(10))
# Out:
# 2

# %%
#PROGRAMME NO. 6
#INDEX()
nums=(10,20,40,60,10)
print(nums.index(10))
# Out:
# 0

# %%
#PROGRAMME NO. 7
#SORTED()
tuple=(12,63,54,25)
sorted_tuple=sorted(tuple)
print(sorted_tuple)
# Out:
# [12, 25, 54, 63]
